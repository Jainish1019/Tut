# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Jainish Patel**
#
# I am intrested in Data Science.

# %% [markdown]
# *I am intrested in Data Science because I love to observe things and make patterns from it.*

# %% [markdown]
# ### Below code will print sum of 4 and 5 which is 9

# %%
print(4+5)
# Out:
# 9

# %% [markdown]
# **Horizontal line**:
#
# hii
# ***
# Hello
#
# **Bullet List**:
#
# * Item 1
# * Item 2
#     * Item 3
#
# **Numbered List**:
#
# 1. Item 1
# 1. Item 2
#     1. Item 3
